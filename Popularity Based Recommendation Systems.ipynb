# %% [markdown]
# ### Popularity Based Recommendation Systems

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from scipy import sparse
from sklearn.metrics.pairwise import cosine_similarity

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Load Data

# %%
df = pd.read_csv('dataset/movies.csv')

# %%
df.head()
# Out:
#     id      title                   genres  \
# 0  862  Toy Story  Animation Comedy Family
# 1  862  Toy Story  Animation Comedy Family
# 2  862  Toy Story  Animation Comedy Family
# 3  862  Toy Story  Animation Comedy Family
# 4  862  Toy Story  Animation Comedy Family
#
#                                             overview  rating spoken_languages  \
# 0  Led by Woody, Andy's toys live happily in his ...     3.0          English
# 1  Led by Woody, Andy's toys live happily in his ...     4.0          English
# 2  Led by Woody, Andy's toys live happily in his ...     5.0          English
# 3  Led by Woody, Andy's toys live happily in his ...     2.0          English
# 4  Led by Woody, Andy's toys live happily in his ...     3.5          English
#
#                            cast          crew  vote_average  vote_count  \
# 0  TomHanks TimAllen DonRickles  JohnLasseter           7.7      5415.0
# 1  TomHanks TimAllen DonRickles  JohnLasseter           7.7      5415.0
# 2  TomHanks TimAllen DonRickles  JohnLasseter           7.7      5415.0
# 3  TomHanks TimAllen DonRickles  JohnLasseter           7.7      5415.0
# 4  TomHanks TimAllen DonRickles  JohnLasseter           7.7      5415.0
#
#    popularity    budget                                           keywords  \
# 0   21.946943  30000000  jealousy toy boy friendship friends rivalry bo...
# 1   21.946943  30000000  jealousy toy boy friendship friends rivalry bo...
# 2   21.946943  30000000  jealousy toy boy friendship friends rivalry bo...
# 3   21.946943  30000000  jealousy toy boy friendship friends rivalry bo...
# 4   21.946943  30000000  jealousy toy boy friendship friends rivalry bo...
#
#       production_companies      revenue  runtime
# 0  Pixar Animation Studios  373554033.0     81.0
# 1  Pixar Animation Studios  373554033.0     81.0
# 2  Pixar Animation Studios  373554033.0     81.0
# 3  Pixar Animation Studios  373554033.0     81.0
# 4  Pixar Animation Studios  373554033.0     81.0

# %%
df.tail()
# Out:
#            id                                              title  \
# 28605  390989                       Sharknado 4: The 4th Awakens
# 28606  159550                     The Last Brickmaker in America
# 28607  392572                                             Rustom
# 28608  402672                                       Mohenjo Daro
# 28609  391698  The Beatles: Eight Days a Week - The Touring Y...
#
#                                 genres  \
# 28605     Comedy Horror ScienceFiction
# 28606                            Drama
# 28607                 Thriller Romance
# 28608  Adventure Drama History Romance
# 28609                Documentary Music
#
#                                                 overview  rating  \
# 28605  The new installment of the Sharknado franchise...     1.5
# 28606  A man must cope with the loss of his wife and ...     5.0
# 28607  Rustom Pavri, an honourable officer of the Ind...     5.0
# 28608  Village lad Sarman is drawn to big, bad Mohenj...     3.0
# 28609  The band stormed Europe in 1963, and, in 1964,...     5.0
#
#       spoken_languages                                     cast  \
# 28605          English      IanZiering TaraReid DavidHasselhoff
# 28606              NaN  SidneyPoitier WendyCrewson JayO.Sanders
# 28607           हिन्दी       AkshayKumar IleanaD'Cruz EshaGupta
# 28608           हिन्दी       HrithikRoshan PoojaHegde KabirBedi
# 28609          English      PaulMcCartney RingoStarr JohnLennon
#
#                     crew  vote_average  vote_count  popularity    budget  \
# 28605  AnthonyC.Ferrante           4.3        88.0    4.574494         0
# 28606      GreggChampion           7.0         1.0    0.038998   8000000
# 28607    TinuSureshDesai           7.3        25.0    7.333139   1000000
# 28608  AshutoshGowariker           6.7        26.0    1.423358  15050000
# 28609          RonHoward           7.6        92.0    7.078301         0
#
#                                                 keywords  \
# 28605  sharkattack sequel farce lasvegas creaturefeature
# 28606                             friendship brickmaking
# 28607                                          bollywood
# 28608                                          bollywood
# 28609                                  music documentary
#
#                                     production_companies     revenue  runtime
# 28605                             The Asylum Syfy BondIt         0.0     85.0
# 28606                               Nasser Entertainment         0.0     85.0
# 28607                               KriArj Entertainment         0.0    150.0
# 28608  UTV Motion Pictures Ashutosh Gowariker Product...  16180000.0    155.0
# 28609                  Imagine Entertainment Apple Corps         0.0     99.0

# %% [markdown]
# ### Data Understanding

# %%
df.shape
# Out:
# (28610, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28610 entries, 0 to 28609
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    28610 non-null  int64
#  1   title                 28610 non-null  object
#  2   genres                28562 non-null  object
#  3   overview              28610 non-null  object
#  4   rating                28610 non-null  float64
#  5   spoken_languages      28408 non-null  object
#  6   cast                  28477 non-null  object
#  7   crew                  28584 non-null  object
#  8   vote_average          28610 non-null  float64
#  9   vote_count            28610 non-null  float64
#  10  popularity            28610 non-null  float64
#  11  budget                28610 non-null  int64
#  12  keywords              27442 non-null  object
#  13  production_companies  27547 non-null  object
#  14  revenue               28610 non-null  float64
#  15  runtime               28610 non-null  float64
# dtypes: float64(6), int64(2), object(8)
# memory usage: 3.5+ MB

# %%
df.describe()
# Out:
#                   id       rating  vote_average    vote_count    popularity  \
# count   28610.000000  28610.00000  28610.000000  28610.000000  28610.000000
# mean    24403.173576      3.16115      6.537078    789.528696      9.542270
# std     46330.742205      1.22482      0.916152   1397.601319     11.588478
# min         2.000000      0.50000      0.000000      0.000000      0.000004
# 25%      2770.000000      2.12500      6.000000     72.000000      5.378874
# 50%     10627.000000      3.00000      6.600000    253.000000      8.434292
# 75%     22292.000000      4.00000      7.200000    844.000000     11.787784
# max    416437.000000      5.00000     10.000000  14075.000000    547.488298
#
#              budget       revenue       runtime
# count  2.861000e+04  2.861000e+04  28610.000000
# mean   2.606797e+07  9.089125e+07    109.332506
# std    4.135381e+07  1.787559e+08     26.329076
# min    0.000000e+00  0.000000e+00      0.000000
# 25%    0.000000e+00  0.000000e+00     95.000000
# 50%    8.000000e+06  2.003674e+07    106.000000
# 75%    3.500000e+07  1.022727e+08    120.000000
# max    3.800000e+08  2.787965e+09   1140.000000

# %%
df.isnull().sum()
# Out:
# id                         0
# title                      0
# genres                    48
# overview                   0
# rating                     0
# spoken_languages         202
# cast                     133
# crew                      26
# vote_average               0
# vote_count                 0
# popularity                 0
# budget                     0
# keywords                1168
# production_companies    1063
# revenue                    0
# runtime                    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 23

# %% [markdown]
# ### Data Cleaning

# %%
df.dropna(inplace=True)

# %%
df = df.drop_duplicates()

# %% [markdown]
# ### Building Popularity Based Recommendation Systems Based on Weighted Rating (WR)

# %% [markdown]
# - We need a metric to score the movie
# - Calculate score of every movie
# - Sort the scores and recommend best rated movie to users
# - We'll use IMDB weighted average score to score the movies

# %% [markdown]
# **Weighted Rating (WR)** :
# ![download.jpg](attachment:download.jpg)

# %% [markdown]
# - v is the number of votes garnered by the movie
# - m is the minimum number of votes required for the movie to be in the chart (the prerequisite)
# - R is the mean rating of the movie from 0 to 10 (mean) = rating
# - C is the mean of **vote_average**(rating) of all the movies in the dataset
#
# source : http://trailerpark.weebly.com/imdb-rating.html?source=post_page

# %%
#Calculate the number of votes garnered by the 80th percentile movie
m = df['vote_count'].quantile(0.80)
m
# Out:
# 1194.0

# %%
## Calculate C
C = df['vote_average'].mean()
C
# Out:
# 6.563996389484373

# %%
df = df[df['vote_count'] >= m]

df.head()
# Out:
#     id      title                   genres  \
# 0  862  Toy Story  Animation Comedy Family
# 1  862  Toy Story  Animation Comedy Family
# 2  862  Toy Story  Animation Comedy Family
# 3  862  Toy Story  Animation Comedy Family
# 4  862  Toy Story  Animation Comedy Family
#
#                                             overview  rating spoken_languages  \
# 0  Led by Woody, Andy's toys live happily in his ...     3.0          English
# 1  Led by Woody, Andy's toys live happily in his ...     4.0          English
# 2  Led by Woody, Andy's toys live happily in his ...     5.0          English
# 3  Led by Woody, Andy's toys live happily in his ...     2.0          English
# 4  Led by Woody, Andy's toys live happily in his ...     3.5          English
#
#                            cast          crew  vote_average  vote_count  \
# 0  TomHanks TimAllen DonRickles  JohnLasseter           7.7      5415.0
# 1  TomHanks TimAllen DonRickles  JohnLasseter           7.7      5415.0
# 2  TomHanks TimAllen DonRickles  JohnLasseter           7.7      5415.0
# 3  TomHanks TimAllen DonRickles  JohnLasseter           7.7      5415.0
# 4  TomHanks TimAllen DonRickles  JohnLasseter           7.7      5415.0
#
#    popularity    budget                                           keywords  \
# 0   21.946943  30000000  jealousy toy boy friendship friends rivalry bo...
# 1   21.946943  30000000  jealousy toy boy friendship friends rivalry bo...
# 2   21.946943  30000000  jealousy toy boy friendship friends rivalry bo...
# 3   21.946943  30000000  jealousy toy boy friendship friends rivalry bo...
# 4   21.946943  30000000  jealousy toy boy friendship friends rivalry bo...
#
#       production_companies      revenue  runtime
# 0  Pixar Animation Studios  373554033.0     81.0
# 1  Pixar Animation Studios  373554033.0     81.0
# 2  Pixar Animation Studios  373554033.0     81.0
# 3  Pixar Animation Studios  373554033.0     81.0
# 4  Pixar Animation Studios  373554033.0     81.0

# %%
def weighted_rating(x,m=m,C=C):
    v = x['vote_count']
    R = x['vote_average']
    return ((v/v+m)*R) + ((m/v+m)*C)

# %%
df['score'] = df.apply(weighted_rating,axis=1)

# %%
df.drop(labels=['rating'],axis=1,inplace=True)

# %%
df.head()
# Out:
#     id      title                   genres  \
# 0  862  Toy Story  Animation Comedy Family
# 1  862  Toy Story  Animation Comedy Family
# 2  862  Toy Story  Animation Comedy Family
# 3  862  Toy Story  Animation Comedy Family
# 4  862  Toy Story  Animation Comedy Family
#
#                                             overview spoken_languages  \
# 0  Led by Woody, Andy's toys live happily in his ...          English
# 1  Led by Woody, Andy's toys live happily in his ...          English
# 2  Led by Woody, Andy's toys live happily in his ...          English
# 3  Led by Woody, Andy's toys live happily in his ...          English
# 4  Led by Woody, Andy's toys live happily in his ...          English
#
#                            cast          crew  vote_average  vote_count  \
# 0  TomHanks TimAllen DonRickles  JohnLasseter           7.7      5415.0
# 1  TomHanks TimAllen DonRickles  JohnLasseter           7.7      5415.0
# 2  TomHanks TimAllen DonRickles  JohnLasseter           7.7      5415.0
# 3  TomHanks TimAllen DonRickles  JohnLasseter           7.7      5415.0
# 4  TomHanks TimAllen DonRickles  JohnLasseter           7.7      5415.0
#
#    popularity    budget                                           keywords  \
# 0   21.946943  30000000  jealousy toy boy friendship friends rivalry bo...
# 1   21.946943  30000000  jealousy toy boy friendship friends rivalry bo...
# 2   21.946943  30000000  jealousy toy boy friendship friends rivalry bo...
# 3   21.946943  30000000  jealousy toy boy friendship friends rivalry bo...
# 4   21.946943  30000000  jealousy toy boy friendship friends rivalry bo...
#
#       production_companies      revenue  runtime         score
# 0  Pixar Animation Studios  373554033.0     81.0  17040.359041
# 1  Pixar Animation Studios  373554033.0     81.0  17040.359041
# 2  Pixar Animation Studios  373554033.0     81.0  17040.359041
# 3  Pixar Animation Studios  373554033.0     81.0  17040.359041
# 4  Pixar Animation Studios  373554033.0     81.0  17040.359041

# %%
df.duplicated().sum()
# Out:
# 4461

# %%
new_df = df.drop_duplicates()

# %%
new_df = new_df.sort_values('score', ascending=False)

new_df[['title','vote_count','vote_average','score','popularity']].head(10)
# Out:
#                                  title  vote_count  vote_average  \
# 3323                     The Godfather      6024.0           8.5
# 1439          The Shawshank Redemption      8358.0           8.5
# 4700                            Psycho      2405.0           8.3
# 4523   One Flew Over the Cuckoo's Nest      3001.0           8.3
# 4718            The Godfather: Part II      3418.0           8.3
# 8655                 Life Is Beautiful      3643.0           8.3
# 17139                    Spirited Away      3968.0           8.3
# 27805                         Whiplash      4376.0           8.3
# 2352                  Schindler's List      4436.0           8.3
# 1350                      Pulp Fiction      8670.0           8.3
#
#               score  popularity
# 3323   17996.212720   41.109264
# 1439   17995.849403   51.645403
# 4700   17759.170488   36.826309
# 4523   17758.523289   35.529554
# 4718   17758.204671   36.629307
# 8655   17758.063051   39.394970
# 17139  17757.886843   41.048867
# 27805  17757.702688   64.299990
# 2352   17757.678464   41.725123
# 1350   17756.815658  140.950236

# %%
weight_average = new_df.sort_values('score',ascending=False)

plt.figure(figsize=(12,6))

axis1=sns.barplot(x=weight_average['score'].head(10), y=weight_average['title'].head(10), data=weight_average, palette='Set2')

plt.title('Best Movies by average votes')
plt.xlabel('Weighted Average Score')
plt.ylabel('Movie Title')
plt.show()

# %% [markdown]
# ### Building Popularity Based Recommendation Systems Based on Popularity Score

# %%
popularity = new_df.sort_values('popularity',ascending=False)

plt.figure(figsize=(12,6))

ax = sns.barplot(x=popularity['popularity'].head(10), y=popularity['title'].head(10), data=popularity, palette='Set2')

plt.title('Most Popular by Votes')
plt.xlabel('Score of Popularity')
plt.ylabel('Movie Title')
plt.show()

# %% [markdown]
# ### Model Serialization & Deserialization

# %%
from pickle import dump

# %%
dump(weight_average,open('movies_popularity.pkl','wb'))

dump(popularity,open('weight_average.pkl','wb'))

# %%
from pickle import load

# %%
popularity = load(open('movies_popularity.pkl', 'rb'))
weighted_score = load(open('weight_average.pkl', 'rb'))

# %%
popularity.head()
# Out:
#        id                            title                 genres  \
# 3323  238                    The Godfather            Drama Crime
# 1439  278         The Shawshank Redemption            Drama Crime
# 4700  539                           Psycho  Drama Horror Thriller
# 4523  510  One Flew Over the Cuckoo's Nest                  Drama
# 4718  240           The Godfather: Part II            Drama Crime
#
#                                                overview  \
# 3323  Spanning the years 1945 to 1955, a chronicle o...
# 1439  Framed in the 1940s for the double murder of h...
# 4700  When larcenous real estate clerk Marion Crane ...
# 4523  While serving time for insanity at a state men...
# 4718  In the continuing saga of the Corleone crime f...
#
#                     spoken_languages  \
# 3323          English Italiano Latin
# 1439                         English
# 4700                         English
# 4523                         English
# 4718  English Italiano Latin Español
#
#                                           cast                crew  \
# 3323           MarlonBrando AlPacino JamesCaan  FrancisFordCoppola
# 1439        TimRobbins MorganFreeman BobGunton       FrankDarabont
# 4700        AnthonyPerkins VeraMiles JohnGavin     AlfredHitchcock
# 4523  JackNicholson LouiseFletcher DannyDeVito         MilošForman
# 4718         AlPacino RobertDuvall DianeKeaton  FrancisFordCoppola
#
#       vote_average  vote_count  popularity    budget  \
# 3323           8.5      6024.0   41.109264   6000000
# 1439           8.5      8358.0   51.645403  25000000
# 4700           8.3      2405.0   36.826309    806948
# 4523           8.3      3001.0   35.529554   3000000
# 4718           8.3      3418.0   36.629307  13000000
#
#                                                keywords  \
# 3323  italy loveatfirstsight lossoffather patriarch ...
# 1439  prison corruption policebrutality prisoncell d...
# 4700  hotel clerk arizona shower rain motel money se...
# 4523  individual rebel self-destruction wheelchair l...
# 4718  italo-american cuba vororte melancholy praise ...
#
#                                    production_companies      revenue  runtime  \
# 3323              Paramount Pictures Alfran Productions  245066411.0    175.0
# 1439             Castle Rock Entertainment Warner Bros.   28341469.0    142.0
# 4700  Paramount Pictures Universal Pictures Shamley ...   32000000.0    109.0
# 4523          United Artists Fantasy Films Warner Bros.  108981275.0    133.0
# 4718             Paramount Pictures The Coppola Company   47542841.0    200.0
#
#              score
# 3323  17996.212720
# 1439  17995.849403
# 4700  17759.170488
# 4523  17758.523289
# 4718  17758.204671

# %%
weighted_score.head()
# Out:
#            id       title                                    genres  \
# 28352  211672     Minions         Family Animation Adventure Comedy
# 27959  177572  Big Hero 6  Adventure Family Animation Action Comedy
# 28144  293660    Deadpool                   Action Adventure Comedy
# 25172   19995      Avatar   Action Adventure Fantasy ScienceFiction
# 27933  245891   John Wick                           Action Thriller
#
#                                                 overview  \
# 28352  Minions Stuart, Kevin and Bob are recruited by...
# 27959  The special bond that develops between plus-si...
# 28144  Deadpool tells the origin story of former Spec...
# 25172  In the 22nd century, a paraplegic Marine is di...
# 27933  Ex-lunatic John Wick comes off his meds to tra...
#
#              spoken_languages                                       cast  \
# 28352                 English        SandraBullock JonHamm MichaelKeaton
# 27959                 English         ScottAdsit RyanPotter DanielHenney
# 28144                 English       RyanReynolds MorenaBaccarin EdSkrein
# 25172         English Español  SamWorthington ZoeSaldana SigourneyWeaver
# 27933  Magyar English Pусский      KeanuReeves MichaelNyqvist AlfieAllen
#
#                 crew  vote_average  vote_count  popularity     budget  \
# 28352      KyleBalda           6.4      4729.0  547.488298   74000000
# 27959  ChrisWilliams           7.8      6289.0  213.849907  165000000
# 28144      TimMiller           7.4     11444.0  187.860492   58000000
# 25172   JamesCameron           7.2     12114.0  185.070892  237000000
# 27933  ChadStahelski           7.0      5499.0  183.870374   20000000
#
#                                                 keywords  \
# 28352  assistant aftercreditsstinger duringcreditssti...
# 27959  brotherbrotherrelationship hero talent revenge...
# 28144  antihero mercenary marvelcomic superhero based...
# 25172  cultureclash future spacewar spacecolony socie...
# 27933  hitman russianmafia revenge murder gangster do...
#
#                                     production_companies       revenue  \
# 28352      Universal Pictures Illumination Entertainment  1.156731e+09
# 27959  Walt Disney Pictures Walt Disney Animation Stu...  6.521054e+08
# 28144  Twentieth Century Fox Film Corporation Marvel ...  7.831130e+08
# 25172  Ingenious Film Partners Twentieth Century Fox ...  2.787965e+09
# 27933  Summit Entertainment Warner Bros. 87Eleven Def...  8.876166e+07
#
#        runtime         score
# 28352     91.0  15487.068998
# 27959    102.0  17159.657899
# 28144    108.0  16681.096538
# 25172    162.0  16442.058660
# 27933    101.0  16203.836932

# %% [markdown]
# ### Thank You
